# %%
# This notebook will use the csv file we found along with the Yelp Fusion API to create a new dataframe
# containing all of the relevent data that we need for our analysis regarding restaurant data.

# %%
# Notes about API use: 5000 daily limit, API key stored in config, 50 cities per request

# %%
# Import dependencies
import os, requests, json
import pandas as pd
from config import api_key

# %%
# Import city and state data
filepath = os.path.join('Resources','happiestcities.csv')
cities_df = pd.read_csv(filepath)
cities_df.head()
# Out:
#    Overall Rank (1 = Best)           City, State  Total Score  \
# 0                        1             Plano, TX        72.30
# 1                        2            Irvine, CA        71.86
# 2                        3           Madison, WI        71.81
# 3                        4           Fremont, CA        71.17
# 4                        5  Huntington Beach, CA        69.74
#
#    Emotional and Physical Well-Being Rank  Income and Employment Rank  \
# 0                                       7                           6
# 1                                      14                          11
# 2                                       3                          14
# 3                                      10                          37
# 4                                       6                          46
#
#    Community and Environment Rank
# 0                               8
# 1                               5
# 2                               7
# 3                               1
# 4                              28

# %%
# Header for accessing API
header = {'Authorization':f'Bearer {api_key}'}

# Set up base url, making sure to pull only restaurants in a 2 mile radius
baseurl = 'https://api.yelp.com/v3/businesses/search?limit=50&radius=3320&term=restaurants&'

# %%
# Create blank list to store data
yelpdata = []

# Loop through happy cities calling for data from Yelp
for place in cities_df['City, State']:

    # Set up URL for calls
    url = baseurl + f'location={place}'

    # Make request and store results
    response = requests.get(url, headers = header).json()

    # Print to screen what the program is doing
    print(f"Retrieving data for {len(response['businesses'])} out of {response['total']} restaurants in {place}......")

    # Loop through business in response
    for i in range(len(response['businesses'])):

        # Handle KeyErrors by skipping businesses
        try:
            # Put relevant data into a dict
            data = {
                'Latitude':response['businesses'][i]['coordinates']['latitude'],
                'Longitude':response['businesses'][i]['coordinates']['longitude'],
                'Name':response['businesses'][i]['name'],
                'Price':response['businesses'][i]['price'],
                'Rating':response['businesses'][i]['rating'],
                'Review Count':response['businesses'][i]['review_count'],
                'Out of Business':response['businesses'][i]['is_closed'],
                'Location':place
            }

            # Add category data to dict
            for j in range(len(response['businesses'][i]['categories'])):
                data[f'Category {j}'] = response['businesses'][i]['categories'][j]['title']

            # Add data to list
            yelpdata.append(data)

        except KeyError:
            print('Error: A relevant piece of data is missing for one of the results, skipping that result......')

# Convert the pulled data to a pandas dataframe
yelp_df = pd.DataFrame(yelpdata)

# Create output folder and save copy of dataframe as a csv
create = os.path.join('Output')
if not os.path.exists(create):    
    os.makedirs(create)
outputpath = os.path.join('Output','restaurantdata.csv')
yelp_df.to_csv(outputpath)
# Out:
# Retrieving data for 50 out of 120 restaurants in Plano, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 229 restaurants in Irvine, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 327 restaurants in Madison, WI......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 352 restaurants in Fremont, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 203 restaurants in Huntington Beach, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 112 restaurants in Fargo, ND......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 103 restaurants in Grand Prairie, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 615 restaurants in San Jose, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 58 restaurants in Scottsdale, AZ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1900 restaurants in San Francisco, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 97 restaurants in Bismarck, ND......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 125 restaurants in Overland Park, KS......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 256 restaurants in Santa Rosa, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 350 restaurants in Austin, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 142 restaurants in Sioux Falls, SD......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 180 restaurants in Pearl City, HI......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 452 restaurants in Glendale, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 343 restaurants in San Diego, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 263 restaurants in St. Paul, MN......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 198 restaurants in Charleston, SC......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 150 restaurants in Gilbert, AZ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 489 restaurants in Anaheim, CA......
# Retrieving data for 50 out of 134 restaurants in Raleigh, NC......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 87 restaurants in Cape Coral, FL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 112 restaurants in Cedar Rapids, IA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 552 restaurants in Minneapolis, MN......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 139 restaurants in Chula Vista, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 156 restaurants in Pembroke Pines, FL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1100 restaurants in Honolulu, HI......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 185 restaurants in Des Moines, IA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 236 restaurants in Irving, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 106 restaurants in Santa Clarita, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 148 restaurants in Chandler, AZ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 105 restaurants in Oceanside, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 141 restaurants in Omaha, NE......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 178 restaurants in Lincoln, NE......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 685 restaurants in Oakland, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 67 restaurants in Billings, MT......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 282 restaurants in Tempe, AZ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 528 restaurants in Garden Grove, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 876 restaurants in Denver, CO......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 312 restaurants in Fort Worth, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 172 restaurants in Burlington, VT......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 124 restaurants in Peoria, AZ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 83 restaurants in Port St. Lucie, FL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 116 restaurants in Boise, ID......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 121 restaurants in Garland, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 191 restaurants in Aurora, CO......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 150 restaurants in El Paso, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 239 restaurants in Arlington, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1800 restaurants in Washington, DC......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 382 restaurants in Charlotte, NC......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 387 restaurants in Fort Lauderdale, FL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1500 restaurants in Seattle, WA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 100 restaurants in Aurora, IL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 143 restaurants in Missoula, MT......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 432 restaurants in Santa Ana, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1600 restaurants in Boston, MA......
# Retrieving data for 50 out of 89 restaurants in Colorado Springs, CO......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 191 restaurants in Durham, NC......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 322 restaurants in Portland, ME......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 137 restaurants in Grand Rapids, MI......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 206 restaurants in Rancho Cucamonga, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 169 restaurants in Salt Lake City, UT......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 240 restaurants in Yonkers, NY......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 98 restaurants in Las Cruces, NM......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 117 restaurants in Rapid City, SD......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 347 restaurants in Dallas, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 59 restaurants in South Burlington, VT......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 162 restaurants in Virginia Beach, VA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 419 restaurants in Long Beach, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 139 restaurants in Anchorage, AK......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 111 restaurants in Cheyenne, WY......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 118 restaurants in Columbia, MD......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 135 restaurants in Mesa, AZ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 35 out of 35 restaurants in Chesapeake, VA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 408 restaurants in Reno, NV......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 286 restaurants in Tallahassee, FL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 346 restaurants in Atlanta, GA......
# Retrieving data for 50 out of 231 restaurants in Oxnard, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 77 restaurants in Nampa, ID......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1200 restaurants in Los Angeles, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 111 restaurants in Orlando, FL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1200 restaurants in Portland, OR......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 198 restaurants in Salem, OR......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 214 restaurants in Brownsville, TX......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 658 restaurants in Pittsburgh, PA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 133 restaurants in Riverside, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 188 restaurants in Fontana, CA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 4000 restaurants in New York, NY......
# Retrieving data for 50 out of 93 restaurants in Nashua, NH......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 161 restaurants in Huntsville, AL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 842 restaurants in Jersey City, NJ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# ...
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 555 restaurants in Las Vegas, NV......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 158 restaurants in Tulsa, OK......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 188 restaurants in Wilmington, DE......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 468 restaurants in Providence, RI......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 352 restaurants in New Haven, CT......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 94 restaurants in Montgomery, AL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 894 restaurants in Baltimore, MD......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 111 restaurants in Jackson, MS......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 73 restaurants in Shreveport, LA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 262 restaurants in Memphis, TN......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 1800 restaurants in Philadelphia, PA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 29 out of 29 restaurants in Columbus, GA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 168 restaurants in Fayetteville, NC......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 106 restaurants in Akron, OH......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 438 restaurants in Cincinnati, OH......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 84 restaurants in Fort Smith, AR......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 217 restaurants in St. Louis, MO......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 43 out of 43 restaurants in Augusta, GA......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 152 restaurants in Mobile, AL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 561 restaurants in Newark, NJ......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 93 restaurants in Huntington, WV......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 113 restaurants in Little Rock, AR......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 43 out of 43 restaurants in Gulfport, MS......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 309 restaurants in Cleveland, OH......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 166 restaurants in Birmingham, AL......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 95 restaurants in Charleston, WV......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 110 restaurants in Toledo, OH......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Retrieving data for 50 out of 133 restaurants in Detroit, MI......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
# Error: A relevant piece of data is missing for one of the results, skipping that result......
