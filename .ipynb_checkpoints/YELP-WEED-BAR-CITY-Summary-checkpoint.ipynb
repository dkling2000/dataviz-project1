# %% [markdown]
# ## Change Log
# ### Monday 3-26 - Added bin for radius

# %%
#Sample usage of the program:
#`IMPORT DATA
from config import api_key
import json
import pprint
import requests
import sys
import pandas as pd

#load CSV File
city_file = "2018happycityrating.csv"
bar_file = "bars_data.csv"
weed_file = "weed_data.csv"

# Read file
happy_cities = pd.read_csv(city_file)
bar_cities = pd.read_csv(bar_file)
weed_cities = pd.read_csv(weed_file)
#happy_cities = happy_cities.rename(columns={"City/State": "Location"})

# %%
#view import data check
happy_cities.head(1)
# Out:
#    Overall Rank   City State City/State  Total Score  \
# 0             1  Plano    TX  Plano, TX         72.3
#
#    Emotional & Physical Well-Being  Income & Employment   \
# 0                                7                     6
#
#    Community & Environment Recreational  Medical
# 0                        8      illegal  CBD oil

# %%
#view import data check
weed_cities.head(1)
# Out:
#            Address             Category 0 Category 1 Category 2       City  \
# 0  719 Griswold St  Cannabis Dispensaries        NaN        NaN  Santa Ana
#
#       Distance         Name  Out of Business Price  Rating  Review Count State
# 0  4983.262815  420 Central            False    $$     4.5           214    CA

# %%
#view import data check
bar_cities.head(1)
# Out:
#             Address      Category 0 Category 1 Category 2 Category 3   City  \
# 0  3701 Dallas Pkwy  American (New)      Pizza  Wine Bars        NaN  Plano
#
#       Distance         Name  Out of Business Price  Rating  Review Count State
# 0  7440.286656  Sixty Vines            False    $$     4.5           966    TX

# %%
#Creating Summary DF for Bar Data by City
bar_cities_group = bar_cities.groupby('City')
cities_rating_avg = bar_cities_group['Rating'].mean()
city_review_count = bar_cities_group['Review Count'].sum()
city_bar_count = bar_cities_group['Name'].count()

bar_summary = pd.DataFrame({"Bars Average Yelp Rating":cities_rating_avg, "Bars Count of Reviews":city_review_count, 
                            "Bar Count":city_bar_count})
bar_summary.head()
# Out:
#              Bars Average Yelp Rating  Bars Count of Reviews  Bar Count
# City
# Aiea                         3.500000                   1594          6
# Akron                        3.792683                   2258         41
# Alameda                      4.125000                   3851          4
# Albuquerque                  3.989796                  11218         49
# Amarillo                     3.558824                   1028         34

# %%
#Creating Summary DF for Weed Data by City
weed_cities_group = weed_cities.groupby('City')
wcities_rating_avg = weed_cities_group['Rating'].mean()
wcity_review_count = weed_cities_group['Review Count'].sum()
wcity_bar_count = weed_cities_group['Name'].count()
weed_summary = pd.DataFrame({"Cannabis Shop Average Yelp Rating":wcities_rating_avg, "Cannabis Shop Count of Reviews":wcity_review_count, 
                            "Cannabis Shop Count":wcity_bar_count})
weed_summary.head()
# Out:
#              Cannabis Shop Average Yelp Rating  \
# City
# Albuquerque                           3.625000
# Anaheim                               3.500000
# Anchorage                             3.884615
# Auburn                                4.000000
# Aurora                                3.281250
#
#              Cannabis Shop Count of Reviews  Cannabis Shop Count
# City
# Albuquerque                              62                    8
# Anaheim                                 168                    5
# Anchorage                                80                   13
# Auburn                                   17                    1
# Aurora                                  423                   16

# %%
#Merging Happy Cities and Bar Summary
# Merge two dataframes using an outer join
merge_city_bar = pd.merge(happy_cities, bar_summary, on="City", how="left") 
merge_city_bar.head()
# Out:
#    Overall Rank              City State            City/State  Total Score  \
# 0             1             Plano    TX             Plano, TX        72.30
# 1             2            Irvine    CA            Irvine, CA        71.86
# 2             3           Madison    WI           Madison, WI        71.81
# 3             4           Fremont    CA           Fremont, CA        71.17
# 4             5  Huntington Beach    CA  Huntington Beach, CA        69.74
#
#    Emotional & Physical Well-Being  Income & Employment   \
# 0                                7                     6
# 1                               14                    11
# 2                                3                    14
# 3                               10                    37
# 4                                6                    46
#
#    Community & Environment Recreational  Medical  Bars Average Yelp Rating  \
# 0                        8      illegal  CBD oil                  3.928571
# 1                        5        legal    legal                  3.810345
# 2                        7  misdemeanor  CBD oil                  4.050000
# 3                        1        legal    legal                  3.592593
# 4                       28        legal    legal                  4.062500
#
#    Bars Count of Reviews  Bar Count
# 0                16083.0       49.0
# 1                22953.0       29.0
# 2                11387.0       50.0
# 3                 8745.0       27.0
# 4                39297.0       56.0

# %%
#Merging Happy Cities and Weed Summary
# Merge two dataframes using an outer join
merge_table_final = pd.merge(merge_city_bar, weed_summary, on="City", how="left") 
merge_table_final.head()
# Out:
#    Overall Rank              City State            City/State  Total Score  \
# 0             1             Plano    TX             Plano, TX        72.30
# 1             2            Irvine    CA            Irvine, CA        71.86
# 2             3           Madison    WI           Madison, WI        71.81
# 3             4           Fremont    CA           Fremont, CA        71.17
# 4             5  Huntington Beach    CA  Huntington Beach, CA        69.74
#
#    Emotional & Physical Well-Being  Income & Employment   \
# 0                                7                     6
# 1                               14                    11
# 2                                3                    14
# 3                               10                    37
# 4                                6                    46
#
#    Community & Environment Recreational  Medical  Bars Average Yelp Rating  \
# 0                        8      illegal  CBD oil                  3.928571
# 1                        5        legal    legal                  3.810345
# 2                        7  misdemeanor  CBD oil                  4.050000
# 3                        1        legal    legal                  3.592593
# 4                       28        legal    legal                  4.062500
#
#    Bars Count of Reviews  Bar Count  Cannabis Shop Average Yelp Rating  \
# 0                16083.0       49.0                                NaN
# 1                22953.0       29.0                                5.0
# 2                11387.0       50.0                                NaN
# 3                 8745.0       27.0                                NaN
# 4                39297.0       56.0                                NaN
#
#    Cannabis Shop Count of Reviews  Cannabis Shop Count
# 0                             NaN                  NaN
# 1                             6.0                  2.0
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN

# %%
merge_table_final.to_csv("merge_table_final.csv", encoding="utf-8", index=False)

# %% [markdown]
# # ## Combine detail files and bin for radius

# %%
merge_city_bar_det = bar_cities.append(weed_cities, ignore_index=True)
merge_city_bar_det = pd.DataFrame(merge_city_bar_det)
bins = [0, 4023, 8046, 12070, 17000]
group_radius = ["2.5 Mile Radius", "5 Mile Radius", "7.5 Mile Radius", "10 Mile Radius"]

merge_city_bar_det['Top-Bottom'] = pd.cut(merge_city_bar_det["Distance"], bins, labels=group_radius)
merge_city_bar_det.head()
# Out:
#              Address          Category 0 Category 1              Category 2  \
# 0   3701 Dallas Pkwy      American (New)      Pizza               Wine Bars
# 1        5880 TX-121  Breakfast & Brunch       Bars  American (Traditional)
# 2  7300 Lone Star Dr      American (New)  Wine Bars                 Seafood
# 3   7300 Dallas Pkwy         Steakhouses    Seafood               Wine Bars
# 4     1006 E 15th St               Pizza    Lounges                 Italian
#
#   Category 3   City     Distance                Name  Out of Business Price  \
# 0        NaN  Plano  7440.286656         Sixty Vines            False    $$
# 1        NaN  Plano  6904.114484     The Biscuit Bar            False     $
# 2        NaN  Plano  6644.335931          Seasons 52            False   $$$
# 3        NaN  Plano  6692.595554  The Capital Grille            False   $$$
# 4        NaN  Plano  7076.169644         Urban Crust            False    $$
#
#    Rating  Review Count State     Top-Bottom
# 0     4.5           966    TX  5 Mile Radius
# 1     4.5           580    TX  5 Mile Radius
# 2     4.0           717    TX  5 Mile Radius
# 3     4.5           479    TX  5 Mile Radius
# 4     4.0           865    TX  5 Mile Radius

# %%
merge_city_bar_det.to_csv("merge_city_bar_det.csv", encoding="utf-8", index=False)

# %% [markdown]
# # ## Merge top and bottom 15

# %%
top_10 = merge_table_final.nlargest(15,'Total Score')
bot_10 = merge_table_final.nsmallest(15,'Total Score')
top_bot = top_10.append(bot_10, ignore_index=True)
bins = [0,50,75]
group_top_bot = ["Bottom 15 Cities", "Top 15 Cities"]
top_bot["Top 15 Bottom 15"] = pd.cut(top_bot["Total Score"], bins, labels=group_top_bot)
top_bot
# Out:
#     Overall Rank              City State            City/State  Total Score  \
# 0              1             Plano    TX             Plano, TX        72.30
# 1              2            Irvine    CA            Irvine, CA        71.86
# 2              3           Madison    WI           Madison, WI        71.81
# 3              4           Fremont    CA           Fremont, CA        71.17
# 4              5  Huntington Beach    CA  Huntington Beach, CA        69.74
# 5              6             Fargo    ND             Fargo, ND        69.57
# 6              7     Grand Prairie    TX     Grand Prairie, TX        69.30
# 7              8          San Jose    CA          San Jose, CA        68.90
# 8              9        Scottsdale    AZ        Scottsdale, AZ        68.24
# 9             10     San Francisco    CA     San Francisco, CA        67.53
# 10            11          Bismarck    ND          Bismarck, ND        67.38
# 11            12     Overland Park    KS     Overland Park, KS        67.37
# 12            13        Santa Rosa    CA        Santa Rosa, CA        67.18
# 13            14            Austin    TX            Austin, TX        67.16
# 14            15       Sioux Falls    SD       Sioux Falls, SD        66.97
# 15           182           Detroit    MI           Detroit, MI        29.19
# 16           181            Toledo    OH            Toledo, OH        39.48
# 17           180        Charleston    WV        Charleston, WV        39.68
# 18           179        Birmingham    AL        Birmingham, AL        40.78
# 19           178         Cleveland    OH         Cleveland, OH        40.81
# 20           177          Gulfport    MS          Gulfport, MS        41.06
# 21           176       Little Rock    AR       Little Rock, AR        41.40
# 22           175        Huntington    WV        Huntington, WV        41.58
# 23           174            Newark    NJ            Newark, NJ        41.86
# 24           173            Mobile    AL            Mobile, AL        42.22
# 25           172           Augusta    GA           Augusta, GA        42.38
# 26           171       Saint Louis    MO       Saint Louis, MO        42.85
# 27           170        Fort Smith    AR        Fort Smith, AR        43.33
# 28           169        Cincinnati    OH        Cincinnati, OH        43.50
# 29           168             Akron    OH             Akron, OH        44.05
#
#     Emotional & Physical Well-Being  Income & Employment   \
# 0                                 7                     6
# 1                                14                    11
# 2                                 3                    14
# 3                                10                    37
# 4                                 6                    46
# 5                                17                    20
# 6                                20                    35
# 7                                 1                    18
# 8                                46                    13
# 9                                 4                     2
# 10                               25                     4
# 11                               22                    56
# 12                               23                    53
# 13                               15                     8
# 14                               11                    67
# 15                              181                   181
# 16                              177                   171
# 17                              180                    65
# 18                              173                   167
# 19                              163                   180
# 20                              179                   162
# 21                              178                   130
# 22                              182                    51
# 23                              141                   182
# 24                              172                   174
# 25                              175                   163
# 26                              162                   170
# 27                              176                   135
# 28                              165                   145
# 29                              154                   166
#
#     Community & Environment    Recreational  Medical  \
# 0                         8         illegal  CBD oil
# 1                         5           legal    legal
# 2                         7     misdemeanor  CBD oil
# 3                         1           legal    legal
# 4                        28           legal    legal
# 5                        24         illegal    legal
# 6                         6         illegal  CBD oil
# 7                        44           legal    legal
# 8                         2         Illegal    legal
# 9                       125           legal    legal
# 10                       45         illegal    legal
# 11                       26     misdemeanor  CBD oil
# 12                        9           legal    legal
# 13                       80         illegal  CBD oil
# 14                       95     misdemeanor  illegal
# 15                      181           legal    legal
# 16                      148  decriminalized    legal
# 17                       93     misdemeanor    legal
# 18                      163     misdemeanor  illegal
# 19                      164  decriminalized    legal
# 20                       94  decriminalized  CBD oil
# 21                      101         Illegal    legal
# 22                       18     misdemeanor    legal
# 23                      180         illegal    legal
# 24                      135     misdemeanor  illegal
# 25                      106  decriminalized  CBD oil
# 26                      160  decriminalized    legal
# 27                      136         Illegal    legal
# 28                      162  decriminalized    legal
# 29                      174  decriminalized    legal
#
#     Bars Average Yelp Rating  Bars Count of Reviews  Bar Count  \
# 0                   3.928571                16083.0       49.0
# 1                   3.810345                22953.0       29.0
# 2                   4.050000                11387.0       50.0
# 3                   3.592593                 8745.0       27.0
# 4                   4.062500                39297.0       56.0
# 5                   3.824324                 1893.0       37.0
# 6                   3.361111                 2684.0       18.0
# 7                   3.820000                48780.0       50.0
# 8                   4.084906                22274.0       53.0
# 9                   4.130000               113196.0       50.0
# 10                  3.590909                 1110.0       22.0
# 11                  3.677419                 4908.0       31.0
# 12                  3.809524                 9631.0       42.0
# 13                  4.160000                42182.0       50.0
# 14                  3.728261                 2029.0       46.0
# 15                  4.060000                20713.0       50.0
# 16                  3.607143                 2303.0       42.0
# 17                  3.937500                27578.0       72.0
# 18                  4.156250                 8650.0       48.0
# 19                  4.140000                14705.0       50.0
# 20                  3.325000                  838.0       20.0
# 21                  3.750000                 3853.0       44.0
# 22                  3.952381                  762.0       21.0
# 23                  3.805556                 5416.0       36.0
# 24                  3.887755                 2767.0       49.0
# 25                  3.708333                 4079.0       48.0
# 26                  4.074468                14664.0       47.0
# 27                  3.763158                  529.0       19.0
# 28                  4.240000                14930.0       50.0
# 29                  3.792683                 2258.0       41.0
#
#     Cannabis Shop Average Yelp Rating  Cannabis Shop Count of Reviews  \
# 0                                 NaN                             NaN
# 1                              5.0000                             6.0
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# 5                                 NaN                             NaN
# 6                                 NaN                             NaN
# 7                              3.8125                           690.0
# 8                              3.5000                            32.0
# 9                              4.3000                          1173.0
# 10                                NaN                             NaN
# 11                                NaN                             NaN
# 12                             3.5000                           210.0
# 13                             5.0000                            20.0
# 14                                NaN                             NaN
# 15                             4.0000                             7.0
# 16                                NaN                             NaN
# 17                                NaN                             NaN
# 18                                NaN                             NaN
# 19                                NaN                             NaN
# 20                                NaN                             NaN
# 21                                NaN                             NaN
# 22                                NaN                             NaN
# 23                                NaN                             NaN
# 24                                NaN                             NaN
# 25                                NaN                             NaN
# 26                                NaN                             NaN
# 27                                NaN                             NaN
# 28                                NaN                             NaN
# 29                                NaN                             NaN
#
#     Cannabis Shop Count  Top 15 Bottom 15
# 0                   NaN     Top 15 Cities
# 1                   2.0     Top 15 Cities
# 2                   NaN     Top 15 Cities
# 3                   NaN     Top 15 Cities
# 4                   NaN     Top 15 Cities
# 5                   NaN     Top 15 Cities
# 6                   NaN     Top 15 Cities
# 7                   8.0     Top 15 Cities
# 8                   1.0     Top 15 Cities
# 9                  15.0     Top 15 Cities
# 10                  NaN     Top 15 Cities
# 11                  NaN     Top 15 Cities
# 12                  1.0     Top 15 Cities
# 13                  1.0     Top 15 Cities
# 14                  NaN     Top 15 Cities
# 15                  3.0  Bottom 15 Cities
# 16                  NaN  Bottom 15 Cities
# 17                  NaN  Bottom 15 Cities
# 18                  NaN  Bottom 15 Cities
# 19                  NaN  Bottom 15 Cities
# 20                  NaN  Bottom 15 Cities
# 21                  NaN  Bottom 15 Cities
# 22                  NaN  Bottom 15 Cities
# 23                  NaN  Bottom 15 Cities
# 24                  NaN  Bottom 15 Cities
# 25                  NaN  Bottom 15 Cities
# 26                  NaN  Bottom 15 Cities
# 27                  NaN  Bottom 15 Cities
# 28                  NaN  Bottom 15 Cities
# 29                  NaN  Bottom 15 Cities

# %%
top_bot.to_csv("top_bot.csv", encoding="utf-8", index=False)

# %% [markdown]
# # ## Create Data Frame for Bar Summary

# %%
bar_topbot_group = top_bot.groupby('Top 15 Bottom 15')
rating_avg = bar_topbot_group['Bars Average Yelp Rating'].mean()
review_count = bar_topbot_group['Bars Count of Reviews'].sum()
bar_count = bar_topbot_group['Bar Count'].sum()
summary = pd.DataFrame({"Average Yelp Rating":rating_avg, "Count of Reviews":review_count, 
                            "Bar Count":bar_count})

summary["Average Yelp Rating"] = summary["Average Yelp Rating"].map("{:.2f}".format)
summary["Count of Reviews"] = summary["Count of Reviews"].map("{:,.2f}".format)
summary["Bar Count"] = summary["Bar Count"].map("{:,.2f}".format)
summary.head()
# Out:
#                  Average Yelp Rating Count of Reviews Bar Count
# Top 15 Bottom 15
# Bottom 15 Cities                3.88       124,045.00    637.00
# Top 15 Cities                   3.84       347,152.00    610.00

# %% [markdown]
# # ## Create Data Frame for Weed Summary

# %%
Weed_df = pd.DataFrame(top_bot[['Top 15 Bottom 15','Total Score','City/State', 'Recreational', 'Medical', 
                                'Cannabis Shop Average Yelp Rating','Cannabis Shop Count of Reviews',
                                'Cannabis Shop Count']])

Weed_df['Recreational'] = Weed_df['Recreational'].replace(
    {'illegal': 'Illegal', 'legal': 'Legal', 'misdemeanor': 'Misdemeanor', 'decriminalized': 'Decriminalized' })

Weed_df['Medical'] = Weed_df['Medical'].replace(
    {'illegal': 'Illegal','CBD oil': 'CBD Oil Legal', 'legal': 'Legal', 'misdemeanor': 'Misdemeanor', 'decriminalized': 'Decriminalized' })

Weed_df.head()
# Out:
#   Top 15 Bottom 15  Total Score            City/State Recreational  \
# 0    Top 15 Cities        72.30             Plano, TX      Illegal
# 1    Top 15 Cities        71.86            Irvine, CA        Legal
# 2    Top 15 Cities        71.81           Madison, WI  Misdemeanor
# 3    Top 15 Cities        71.17           Fremont, CA        Legal
# 4    Top 15 Cities        69.74  Huntington Beach, CA        Legal
#
#          Medical  Cannabis Shop Average Yelp Rating  \
# 0  CBD Oil Legal                                NaN
# 1          Legal                                5.0
# 2  CBD Oil Legal                                NaN
# 3          Legal                                NaN
# 4          Legal                                NaN
#
#    Cannabis Shop Count of Reviews  Cannabis Shop Count
# 0                             NaN                  NaN
# 1                             6.0                  2.0
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN

# %%
Weed_df_group = Weed_df.groupby('Recreational')
Weed_rec_group = Weed_df_group ['Recreational'].count()
Weed_df_group2 = Weed_df.groupby('Medical')
Weed_med_group = Weed_df_group2 ['Medical'].count()

Weed_rec_group, Weed_med_group
# Out:
# (Recreational
#  Decriminalized    7
#  Illegal           9
#  Legal             7
#  Misdemeanor       7
#  Name: Recreational, dtype: int64, Medical
#  CBD Oil Legal     7
#  Illegal           3
#  Legal            20
#  Name: Medical, dtype: int64)
