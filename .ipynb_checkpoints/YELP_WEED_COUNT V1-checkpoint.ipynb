# %%
#Sample usage of the program:
#`python sample.py --term="bars" --location="San Francisco, CA"`
from config import api_key
import json
import pprint
import requests
import sys
import pandas as pd

#load CSV File
file_to_load = "2018happycityrating.csv"

# Read file
happy_cities = pd.read_csv(file_to_load)

# %%
happy_cities.head()
# Out:
#    Overall Rank              City State  Total Score  \
# 0             1             Plano    TX        72.30
# 1             2            Irvine    CA        71.86
# 2             3           Madison    WI        71.81
# 3             4           Fremont    CA        71.17
# 4             5  Huntington Beach    CA        69.74
#
#    Emotional & Physical Well-Being  Income & Employment   \
# 0                                7                     6
# 1                               14                    11
# 2                                3                    14
# 3                               10                    37
# 4                                6                    46
#
#    Community & Environment
# 0                        8
# 1                        5
# 2                        7
# 3                        1
# 4                       28

# %%
#Create a data frame that will store the bar information from 
happy_bars = pd.DataFrame({'City' : []})
happy_bars["State"] = ""
happy_bars["Category"] = ""
#happy_bars = cities_df.rename(columns={0 : "City"})
happy_bars["Rating"] = ""
happy_bars["Review Count"] = ""
happy_bars["Name"] = ""
happy_bars["Price"] = ""

happy_bars.head()
# Out:
# Empty DataFrame
# Columns: [City, State, Category, Rating, Review Count, Name, Price]
# Index: []

# %%
# Set up URL for test
city = 'New York City'
categories = "cannabiscollective, cannabisdispensaries"
header = {'Authorization':f'Bearer {api_key}'}
radius = '13220'
url = f'https://api.yelp.com/v3/businesses/search?limit=50&location={city}&categories={categories}&radius={radius}'

print(url)

# Make test request and show results
response = requests.get(url, headers = header).json()

print(json.dumps(response, indent=2, sort_keys=True))
# Out:
# https://api.yelp.com/v3/businesses/search?limit=50&location=New York City&categories=cannabiscollective, cannabisdispensaries&radius=13220
# {
#   "businesses": [],
#   "region": {
#     "center": {
#       "latitude": 40.70544486444615,
#       "longitude": -73.99429321289062
#     }
#   },
#   "total": 0
# }

# %%
bar_data = []

for index, row in happy_cities.iterrows():
    city = row["City"]

    categories = "cannabiscollective, cannabisdispensaries"
    header = {'Authorization':f'Bearer {api_key}'}
    radius = '3220'
    
    query_url = f'https://api.yelp.com/v3/businesses/search?limit=50&location={city}&categories={categories}&radius={radius}'
    bar_response = requests.get(query_url, headers = header)
    bar_json = bar_response.json()
    
    for i in range(len(bar_json['businesses'])):
        try:
            
            data = {
               
               'Name':response['businesses'][i]['name'],
               'Price':response['businesses'][i]['price'],
               'Rating':response['businesses'][i]['rating'],
               'Review Count':response['businesses'][i]['review_count'],
               'Out of Business':response['businesses'][i]['is_closed'],
               'Location':response['businesses'][i]['location']['city']
                             
                        }
            
            # Add category data to dict
            #for j in range(len(response['businesses'][i]['categories'])):
             #   data[f'Category {j}'] = response['businesses'][i]['categories'][j]['title']
                    
              # Add data to list
            bar_data.append(data)
        except KeyError:
            print('KeyError: skipping')
#weed_df = pd.DataFrame(bar_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-7d308cbbd571> in <module>
#      17             data = {
#      18
# ---> 19                'Name':response['businesses'][i]['name'],
#      20                'Price':response['businesses'][i]['price'],
#      21                'Rating':response['businesses'][i]['rating'],
#
# IndexError: list index out of range

# %%
weed_df.head()

# %%
weed_df.to_csv("weed_data.csv", encoding="utf-8", index=False)
weed_df.head()

# %%
bar_data = []

for index, row in happy_cities.iterrows():
    city = row["City"]

    #categories = "cannabiscollective, cannabisdispensaries"
    categories = "bars"
    header = {'Authorization':f'Bearer {api_key}'}
    radius = '3220'
    
    query_url = f'https://api.yelp.com/v3/businesses/search?limit=50&location={city}&categories={categories}&radius={radius}'
    bar_response = requests.get(query_url, headers = header)
    bar_json = bar_response.json()
    
    try:    
        for i in range(len(bar_json['businesses'])):
            try:
            
                data = {
               
                   'Name':response['businesses'][i]['name'],
                   'Price':response['businesses'][i]['price'],
                   'Rating':response['businesses'][i]['rating'],
                   'Review Count':response['businesses'][i]['review_count'],
                   'Out of Business':response['businesses'][i]['is_closed'],
                   'Location':response['businesses'][i]['location']['city']
                             
                            }
            
                # Add category data to dict
               # for j in range(len(response['businesses'][i]['categories'])):
                #    data[f'Category {j}'] = response['businesses'][i]['categories'][j]['title']
                    
              # Add data to list
                bar_data.append(data)
            except KeyError:
                print('KeyError: skipping')
    except:
        print('Nothing in Category')
weed_df = pd.DataFrame(bar_data)
# Out:
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# Nothing in Category
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-90d8344385c3> in <module>
#      10
#      11     query_url = f'https://api.yelp.com/v3/businesses/search?limit=50&location={city}&categories={categories}&radius={radius}'
# ---> 12     bar_response = requests.get(query_url, headers = header)
#      13     bar_json = bar_response.json()
#      14
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# C:\Users\MMagliar\Anaconda3\envs\PythonData\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1904         :return: None.
#    1905         """
# -> 1906         result = _lib.SSL_do_handshake(self._ssl)
#    1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# KeyboardInterrupt:

# %%
weed_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
bar_data = []
city = "New York"
#for index, row in happy_cities.iterrows():
    #city = row["City"]
    

    #categories = "cannabiscollective, cannabisdispensaries"
    categories = "bars"
    header = {'Authorization':f'Bearer {api_key}'}
    radius = '3220'
    
    query_url = f'https://api.yelp.com/v3/businesses/search?limit=50&location={city}&categories={categories}&radius={radius}'
    bar_response = requests.get(query_url, headers = header)
    bar_json = bar_response.json()
    
      
    for i in range(len(bar_json['businesses'])):
            
            try:
            
                data = {
               
                   'Name':bar_json['businesses'][i]['name'],
                   'Price':bar_json['businesses'][i]['price'],
                   'Rating':bar_json['businesses'][i]['rating'],
                   'Review Count':bar_json['businesses'][i]['review_count'],
                   'Out of Business':bar_json['businesses'][i]['is_closed'],
                   'Location':bar_json['businesses'][i]['location']['city']
                             
                            }
            
                # Add category data to dict
               # for j in range(len(response['businesses'][i]['categories'])):
                #    data[f'Category {j}'] = response['businesses'][i]['categories'][j]['title']
                    
              # Add data to list
                bar_data.append(data)
            except KeyError:
                print('KeyError: skipping')
    
weed_df = pd.DataFrame(bar_data)

# %%
weed_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f19b4c1a3527> in <module>
# ----> 1 weed_df.head()
#
# NameError: name 'weed_df' is not defined

# %%
bar_data = []

for index, row in happy_cities.iterrows():
    city = row["City"]

    categories = "cannabiscollective, cannabisdispensaries"
    header = {'Authorization':f'Bearer {api_key}'}
    radius = '3220'
    
    query_url = f'https://api.yelp.com/v3/businesses/search?limit=50&location={city}&categories={categories}&radius={radius}'
    bar_response = requests.get(query_url, headers = header)
    bar_json = bar_response.json()
    
    for i in range(len(bar_json['businesses'])):
        try:
            
            data = {
               
               'Name':bar_json['businesses'][i]['name'],
               'Price':bar_json['businesses'][i]['price'],
               'Rating':bar_json['businesses'][i]['rating'],
               'Review Count':bar_json['businesses'][i]['review_count'],
               'Out of Business':bar_json['businesses'][i]['is_closed'],
               'Location':bar_json['businesses'][i]['location']['city']
                             
                        }
            
            # Add category data to dict
            #for j in range(len(response['businesses'][i]['categories'])):
             #   data[f'Category {j}'] = response['businesses'][i]['categories'][j]['title']
                    
              # Add data to list
            bar_data.append(data)
        except KeyError:
            print('KeyError: skipping')
weed_df = pd.DataFrame(bar_data)
# Out:
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping
# KeyError: skipping

# %%
weed_df.head
# Out:
# <bound method NDFrame.head of          Location                                              Name  \
# 0        San Jose                                Elemental Wellness
# 1   San Francisco                                              SAVA
# 2        San Jose                                Elemental Wellness
# 3   San Francisco                                              SAVA
# 4   San Francisco       MediThrive: Dispensary and Delivery Service
# 5   San Francisco                                              SAVA
# 6     Los Angeles  Western Caregivers / California Cannabis Melrose
# 7     Los Angeles                                          Kushland
# 8     Los Angeles                                       The Pottery
# 9     Los Angeles                           Green Valley Collective
# 10  San Francisco                                              SAVA
# 11       San Jose                                Elemental Wellness
# 12         Denver                         Reefer Madness Dispensary
# 13       Torrance                           Green Cross of Torrance
# 14   Sherman Oaks                                   The Higher Path
# 15    Los Angeles  Western Caregivers / California Cannabis Melrose
# 16       Torrance                           Green Cross of Torrance
# 17    Los Angeles                                       The Pottery
# 18    Los Angeles  Western Caregivers / California Cannabis Melrose
# 19    Los Angeles                                          Kushland
# 20    Los Angeles                                       The Pottery
# 21     Sacramento                         A Therapeutic Alternative
#
#     Out of Business Price  Rating  Review Count
# 0             False    $$     4.0           132
# 1             False    $$     5.0            24
# 2             False    $$     4.0           132
# 3             False    $$     5.0            24
# 4             False    $$     4.0           350
# 5             False    $$     5.0            24
# 6             False    $$     4.5            31
# 7             False    $$     3.5             7
# 8             False    $$     3.0             6
# 9             False    $$     3.5            57
# 10            False    $$     5.0            24
# 11            False    $$     4.0           132
# 12            False    $$     3.5             7
# 13            False    $$     4.0            38
# 14            False    $$     4.5           146
# 15            False    $$     4.5            31
# 16            False    $$     4.0            38
# 17            False    $$     3.0             6
# 18            False    $$     4.5            31
# 19            False    $$     3.5             7
# 20            False    $$     3.0             6
# 21            False   $$$     3.5            68  >
